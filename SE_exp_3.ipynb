# %% [markdown]
# <a href="https://colab.research.google.com/github/praneel0576/software-lab_0576/blob/main/SE_exp_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the quadratic function
def quadratic(x, a=-1, b=0, c=10):
 return a*x**2+b*x+c

# %%
# Define the stages of the Waterfall Model
stages = ["Requirements", "Design", "Implementation", "Testing", "Deployment", "Maintenance"]
x_positions = np.linspace(-2, 2, len(stages)) # Equally spaced x positions
y_positions = quadratic(x_positions) # Compute y positions using the quadratic function

# Plot the quadratic curve
x_curve = np.linspace(-2.5, 2.5, 500) #Fixed: assigned the result of np.linspace to x_curve
y_curve = quadratic(x_curve)  #Fixed: assigned the result of quadratic(x_curve) to y_curve
plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle="--", label="Quadratic Curve")
# Add markers and connect them with vertical lines to create the waterfall effect
for i in range(len(stages)):
    if i > 0:
        # Draw a vertical drop to simulate a waterfall
        plt.plot(
            [x_positions[i-1], x_positions[i]], # Horizontal segment
            [y_positions[i-1], y_positions[i-1]],
            color="blue",
            linewidth=2
        )
        plt.plot(
            [x_positions[i], x_positions[i]], # Vertical drop
            [y_positions[i-1], y_positions[i]],
            color="blue",
            linewidth=2
        )

# %%
# Define the stages of the Waterfall Model
stages = ["Requirements", "Design", "Implementation", "Testing", "Deployment", "Maintenance"]
x_positions = np.linspace(-2, 2, len(stages)) # Equally spaced x positions
y_positions = quadratic(x_positions) # Compute y positions using the quadratic function

# Plot the quadratic curve
x_curve = np.linspace(-2.5, 2.5, 500) #Fixed: assigned the result of np.linspace to x_curve
y_curve = quadratic(x_curve)  #Fixed: assigned the result of quadratic(x_curve) to y_curve
plt.figure(figsize=(10, 6))
plt.plot(x_curve, y_curve, color="blue", linestyle="--", label="Quadratic Curve")
# Add markers and connect them with vertical lines to create the waterfall effect
for i in range(len(stages)):
    plt.scatter(x_positions[i], y_positions[i], color="red", zorder=5) # Indented to be inside the loop
    plt.text(x_positions[i], y_positions[i] + 0.3, stages[i], ha="center", fontsize=10) # Indented to be inside the loop
    if i > 0:
        # Draw a vertical drop to simulate a waterfall
        plt.plot(
            [x_positions[i-1], x_positions[i]], # Horizontal segment
            [y_positions[i-1], y_positions[i-1]],
            color="blue",
            linewidth=2
        )
        plt.plot(
            [x_positions[i], x_positions[i]], # Vertical drop
            [y_positions[i-1], y_positions[i]],
            color="blue",
            linewidth=2
        )


# Style the plot
plt.title("Waterfall Model Representation Using Quadratic Curve", fontsize=14)
plt.xlabel("stages", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.axhline(0, color="black", linewidth=0.5, linestyle="--")
plt.axvline(0, color="black", linewidth=0.5, linestyle="--")
plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.show()
